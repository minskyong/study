# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sales_df = pd.DataFrame({
    "month": [
        1, 2, 3, 4, 5, 6,
        1, 2, 3, 4, 5, 6,
        1, 2, 3, 4, 5, 6,
    ],
    "region": [
        "Seoul", "Seoul", "Seoul",
        "Seoul", "Seoul", "Seoul",
        "Busan", "Busan", "Busan",
        "Busan", "Busan", "Busan",
        "Daejeon", "Daejeon", "Daejeon",
        "Daejeon", "Daejeon", "Daejeon",
    ],
    "sales": [
        120, 138, 155, 171, 188, 205,
        105, 118, 132, 149, 163, 178,
        92, 106, 119, 133, 148, 162,
    ],
    "advertising": [
        10, 12, 15, 18, 21, 24,
        9, 11, 13, 16, 19, 22,
        7, 9, 12, 14, 17, 20,
    ],
    "visitors": [
        800, 900, 1010, 1130, 1260, 1400,
        720, 810, 900, 1010, 1120, 1250,
        650, 730, 820, 910, 1020, 1140,
    ],
})

sales_df
# Out:
#     month   region  sales  advertising  visitors
# 0       1    Seoul    120           10       800
# 1       2    Seoul    138           12       900
# 2       3    Seoul    155           15      1010
# 3       4    Seoul    171           18      1130
# 4       5    Seoul    188           21      1260
# 5       6    Seoul    205           24      1400
# 6       1    Busan    105            9       720
# 7       2    Busan    118           11       810
# 8       3    Busan    132           13       900
# 9       4    Busan    149           16      1010
# 10      5    Busan    163           19      1120
# 11      6    Busan    178           22      1250
# 12      1  Daejeon     92            7       650
# 13      2  Daejeon    106            9       730
# 14      3  Daejeon    119           12       820
# 15      4  Daejeon    133           14       910
# 16      5  Daejeon    148           17      1020
# 17      6  Daejeon    162           20      1140

# %%
sns.set_theme()          #테마 수정

sns.lineplot(
    data = sales_df,
    x= 'month',
    y= 'sales',
    hue = 'region',
    marker = 'o'
)
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %%
sns.set_theme(style = 'darkgrid') # 직접 넣기 가능 

plt.plot(
    [1,2,3,4],
    [10,11,12,13],
    marker = 'o'
)

# %%
sns.set_theme(
    
    style = 'whitegrid',
    context = 'notebook',
    palette = 'deep'
    ) 

sns.lineplot(
    data = sales_df,
    x= 'month',
    y= 'sales',
    hue = 'region',
    marker = 'o'
)

plt.show()

# %%
# 옵션 찾기

style = sns.axes_style()# 함수 설명 

# 예시 

style['axes.facecolor']
# Out:
# 'white'

# %% [markdown]
# # 색상
#
# - color palette
# - 서로 다른 범주 구분 / 범주형 팔레트
# - 작은 값에서 큰 값으로 변화 표현 / 연속형 팔레트
#
# - 특정 기준보다 낮거나 높은 방향 표현 / 발산형 팔레트

# %%
sns.color_palette(

    'deep',
    n_colors = 6,
)

sns.color_palette(

    'pastel',
    n_colors = 6,
)

p = sns.color_palette(

    'muted',
     6,
)

sns.palplot(p)

# %%
sns.set_theme(
    
    style = 'whitegrid',
    context = 'notebook',
    palette = 'pastel'
    ) 

sns.lineplot(
    data = sales_df,
    x= 'month',
    y= 'sales',
    hue = 'region',
    marker = 'o'
)
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %%
sns.scatterplot(
    data = sales_df,
    x= 'month',
    y= 'sales',
    hue = 'region',
    palette = 'Set2',
    s = 80)
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %% [markdown]
# ## 연속형 팔레트
# - 수치가 작은 값에서 큰 값으로 연속적으로 변화할 때 사용
# - 방문객 수가 100, 700, 1400... 순서와 크기를 갖는 수치형 데이터

# %%
sns.scatterplot(
    data = sales_df,
    x= 'advertising',
    y= 'sales',
    hue = 'visitors',
    palette = 'rocket',
    s = 100

)
# Out:
# <Axes: xlabel='advertising', ylabel='sales'>

# %%
df = pd.DataFrame([
       [10,20,30],
       [20,40,60],
       [70,90,110]], 
index = ['a','b','c'],

columns = ['x','y','z'])

sns.heatmap(
    data = df,
    annot =True,
    

)
# Out:
# <Axes: >

# %%
rng = np.random.default_rng(42)

n= 150

advertising = rng.normal(50,12,n)
visitors = 400 + 8 * advertising + rng.normal(0,80,n)

conversion_rate = rng.normal(0.12, 0.02,n)

buyers = visitors * conversion_rate + rng.normal(0,5,n)
sales = 20+0.7*advertising+0.35 * buyers + rng.normal(0,8,n)
satisfaction = 3.0 + 0.006 * sales + rng.normal(0, 0.35, n)

channel =rng.choice(
            ['online','offline'],
            size = n
                    )


customer_df = pd.DataFrame(
    {'advertising' : advertising.round(1),
     'visitors' : visitors.round(0).astype(int),
     'buyers' : buyers.round(0).astype(int),
     'sales' : sales.round(1),
     
     'satisfaction' : np.clip(
                        satisfaction,
                        1,5),round(2),
     'channel':  channel})
# Out:
#   Cell In[67], line 27
#     1,5),round(2),
#                 ^
# SyntaxError: ':' expected after dictionary key

# %%
rng = np.random.default_rng(42)

n = 150

advertising = rng.normal(50,12,n)
visitors = 400 + 8 * advertising + rng.normal(0,80,n)

conversion_rate = rng.normal(0.12, 0.02, n)
buyers = visitors * conversion_rate + rng.normal(0,5,n)

sales = 20 + 0.7 * advertising + 0.35 * buyers + rng.normal(0,8,n)
satisfaction = 3.0 + 0.006 * sales + rng.normal(0, 0.35, n)

channel = rng.choice(
    ['Online', 'Offline'],
    size=n
)

customer_df = pd.DataFrame({
    'advertising': advertising.round(1),
    'visitors': visitors.round(0).astype(int),
    'buyers': buyers.round(0).astype(int),
    'sales': sales.round(1),
    'statisfaction': np.clip(
        satisfaction,
        1,
        5,
    ).round(2),
    'channel': channel,
})

customer_df.head()
# Out:
#    advertising  visitors  buyers  sales  statisfaction  channel
# 0         53.7       817     126  105.6           3.64  Offline
# 1         37.5       617      57   61.6           3.26   Online
# 2         59.0       738     111  110.4           3.31   Online
# 3         61.3       851     107   95.3           4.29  Offline
# 4         26.6       608      73   58.9           3.98   Online
