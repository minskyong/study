# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.DataFrame({
    "product": [
        "노트북", "모니터", "키보드", "마우스",
        "태블릿", "헤드셋", "웹캠", "스피커",
        "SSD", "공유기", "스마트폰", "충전기",
    ],
    "category": [
        "PC", "PC", "주변기기", "주변기기",
        "모바일", "주변기기", "주변기기", "주변기기",
        "PC", "네트워크", "모바일", "모바일",
    ],
    "region": [
        "서울", "부산", "서울", "대전",
        "부산", "서울", "대전", "부산",
        "서울", "대전", "부산", "서울",
    ],
    "quantity": [
        32, 28, 45, 50,
        26, 38, 20, 24,
        35, 18, 30, 55,
    ],
    "sales": [
        320, 210, 150, 110,
        260, 140, 90, 120,
        180, 100, 360, 80,
    ],
    "profit": [
        72, 48, 41, 28,
        58, 35, 21, 26,
        46, 22, 81, 18,
    ],
    "satisfaction": [
        4.6, 4.3, 4.5, 4.2,
        4.7, 4.1, 4.0, 4.3,
        4.5, 3.9, 4.8, 4.1,
    ],
})

df
# Out:
#    product category region  quantity  sales  profit  satisfaction
# 0      노트북       PC     서울        32    320      72           4.6
# 1      모니터       PC     부산        28    210      48           4.3
# 2      키보드     주변기기     서울        45    150      41           4.5
# 3      마우스     주변기기     대전        50    110      28           4.2
# 4      태블릿      모바일     부산        26    260      58           4.7
# 5      헤드셋     주변기기     서울        38    140      35           4.1
# 6       웹캠     주변기기     대전        20     90      21           4.0
# 7      스피커     주변기기     부산        24    120      26           4.3
# 8      SSD       PC     서울        35    180      46           4.5
# 9      공유기     네트워크     대전        18    100      22           3.9
# 10    스마트폰      모바일     부산        30    360      81           4.8
# 11     충전기      모바일     서울        55     80      18           4.1
