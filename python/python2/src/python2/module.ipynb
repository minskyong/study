# %% [markdown]
# # 모듈
#
# - 프로그램이 커질수록 모든 코드를 하나의 파일에 담는것은 불가능에 가까워 모듈이란 단위를 사용
# - 모듈은 파이썬 코드를 담고 있는 파이썬 파일 .py 하나를 의미
# - 관련된 함수 등을 하나의 파일로 묶어서 사용하고 구조적으로 관리할 수 있게 하는 단위

# %% [markdown]
# ## import
# 다른 모듈의 내용을 현재 코드에서 사용할 수 있도록 불러오는 행위

# %%
import math
import os
import sys

#as 통한 줄이기도 가능
"""
import math as mt
"""
# from --- import ---
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from math import sqrt, pi
print(pi)

print(sqrt(55))
# Out:
# 3.141592653589793
# 7.416198487095663

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
a = 8
for i in range(a):
    print('*' * (i+1))
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********

# %%
a = 8

for i in range(a):
    print(" " * (a - (i + 1)))
    print(" *"* (i+1))
# Out:
#
#  *
#
#  * *
#
#  * * *
#
#  * * * *
#
#  * * * * *
#
#  * * * * * *
#
#  * * * * * * *
#
#  * * * * * * * *
