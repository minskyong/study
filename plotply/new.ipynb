# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.DataFrame({
    "product": [
        "노트북", "모니터", "키보드", "마우스",
        "태블릿", "헤드셋", "웹캠", "스피커",
        "SSD", "공유기", "스마트폰", "충전기",
    ],
    "category": [
        "PC", "PC", "주변기기", "주변기기",
        "모바일", "주변기기", "주변기기", "주변기기",
        "PC", "네트워크", "모바일", "모바일",
    ],
    "region": [
        "서울", "부산", "서울", "대전",
        "부산", "서울", "대전", "부산",
        "서울", "대전", "부산", "서울",
    ],
    "quantity": [
        32, 28, 45, 50,
        26, 38, 20, 24,
        35, 18, 30, 55,
    ],
    "sales": [
        320, 210, 150, 110,
        260, 140, 90, 120,
        180, 100, 360, 80,
    ],
    "profit": [
        72, 48, 41, 28,
        58, 35, 21, 26,
        46, 22, 81, 18,
    ],
    "satisfaction": [
        4.6, 4.3, 4.5, 4.2,
        4.7, 4.1, 4.0, 4.3,
        4.5, 3.9, 4.8, 4.1,
    ],
})

df

# %%
fig = px.line( 
        df,
        x = 'month',
     y = 'sales',
     markers = True,
    title ='월별 매출 변화량 '
