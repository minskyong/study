# %% [markdown]
# # 아이디어
#
# 결국엔 데이터 긁어오기

# %% [markdown]
# # 항만 파트
#
#    선박 운항 및 위치 데이터(AIS): 선박의 실시간 위치, 입출항 시간, 해상 대기 시간 및 접안 시간 분석
#    터미널 하역 및 야드 데이터: 컨테이너 적·양하 작업 현황, 장비(야드 트랙터 등) 가동률 및 배차 효율성 분석
#    배후 교통 및 물동량 데이터: 항만 주변 화물차 통행량, 도로 정체 구간, 연간 화물 선적·반출입 실적 분석
#
#
#
#
# 1.부산항 선박 대기시간 줄이기? ais로 파악 가능?
#
#
# 해상 대기 시간 및 접안 시간 분석 -> 걸리는 시간 만큼 적재 적하 오래 걸림 ->
# . 부산항 컨테이너 터미널 물류 프로세스 병목구간 분석
#    -구간 : 입항 - 접안 / 접안 -하역/ 하역-종료/ 종료 -반출/
#     반출-항만이탈/ 이 구간으로 병목현상 찾을 수 있을까.
#
#
#
#
#     ## 단순히 하나를 생각하지말고 여러개를 합친다면?
#
#
# 3. 혼잡도라고 크게 잡아서 선박대기시간/터미널 처리량/야드 점유율/화물차 체류시간 다 합치기?

# %% [markdown]
# ## 디자인
# 어떤식으로?
