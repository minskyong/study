# %% [markdown]
# # 함수
# 함수는 특정한 목적을 위해 작성된 코드의 묶음에 이름을 붙여서 재사용할 수 있도록 정의
# 'print()'

# %% [markdown]
# ## 함수의 구조
#
# def 함수_이름():   #정의부  def 이후 = 시그니처 ()= 파라미터
#     명령문         #본문

# %%
def sum(a,b):
    print(f'sum의 결과값은 {a+b}')

sum(5,3)
# Out:
# sum의 결과값은 8

# %%
def multiply(a, b):
    result = a * b
    return result

result = multiply(3, 3)
print(result)
# Out:
# 9

# %%
a : int = 10
b : float = 3.14
c : str = "hi"


def func1() -> None:
    print()

def func2(a: int, b: float) -> None:
    return a*b
def func3(a: int, b: int) -> None:
    return a*b

def func4(a: int , b: int) -> None:
    '''
    두 정수를 합산하는 숫자
    '''
    return a*b

# %%
func1()
func4()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 func1()
# ----> 2 func4()
#
# NameError: name 'func4' is not defined
