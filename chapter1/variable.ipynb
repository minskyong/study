# %% [markdown]
# # 변수
#
# 변수는 메모리상 지정된 값을 가르키는 이름

# %%
print("i am ironman")
# Out:
# i am ironman

# %%
a = 10
b= 15
print( "a+b는",  a+b)
# Out:
# a+b는 25

# %% [markdown]
# # 변수의 초기화
# a에 10을 넣은게 아님 a 라는 변수에 10을 할당(allocate)

# %% [markdown]
# ** 변수명에는 특수문자 / 숫자 사용 불가능 단 _는 사용가능**

# %% [markdown]
# # snake case, camel case
# 파이썬 변수 명은 snake case을 써야함.
#
# snake case = " my_name_is_gyeongmin"
# camel case = " myNameIsGyeongmin"

# %%
import keyword 

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 설정한 변수에 초기값만 초기화
# 후에 설정한 값은 재설정

# %%
a_10 = 10
a_10 = 100
print(a_10)
# Out:
# 100
